# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnissan-BIA/Assignments/blob/main/Assignment_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.datasets import fashion_mnist
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

# %% [markdown]
# # Load dataset

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Class labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print("Training data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %% [markdown]
# # Visualize images

# %%
plt.figure(figsize=(12, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(class_names[y_train[i]])
    plt.axis('off')
plt.suptitle("Sample Images from Fashion MNIST")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing

# %%
# Normalize pixel values to range [0, 1]
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode target labels
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# %% [markdown]
# # Build feedforward neural network

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),     # convert 28x28 image into 784 features
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Compile model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Train model

# %%
history = model.fit(
    X_train, y_train_cat,
    epochs=15,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7834 - loss: 0.6098 - val_accuracy: 0.8446 - val_loss: 0.4238
# Epoch 2/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8427 - loss: 0.4371 - val_accuracy: 0.8650 - val_loss: 0.3772
# Epoch 3/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8533 - loss: 0.4046 - val_accuracy: 0.8625 - val_loss: 0.3804
# Epoch 4/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8612 - loss: 0.3817 - val_accuracy: 0.8701 - val_loss: 0.3533
# Epoch 5/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8661 - loss: 0.3639 - val_accuracy: 0.8754 - val_loss: 0.3427
# Epoch 6/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8697 - loss: 0.3554 - val_accuracy: 0.8682 - val_loss: 0.3621
# Epoch 7/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8739 - loss: 0.3421 - val_accuracy: 0.8694 - val_loss: 0.3517
# Epoch 8/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8763 - loss: 0.3314 - val_accuracy: 0.8844 - val_loss: 0.3236
# Epoch 9/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8812 - loss: 0.3216 - val_accuracy: 0.8780 - val_loss: 0.3444
# Epoch 10/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8827 - loss: 0.3183 - val_accuracy: 0.8763 - val_loss: 0.3342
# Epoch 11/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8839 - loss: 0.3107 - val_accuracy: 0.8833 - val_loss: 0.3249
# Epoch 12/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8861 - loss: 0.3049 - val_accuracy: 0.8793 - val_loss: 0.3285
# Epoch 13/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8861 - loss: 0.3038 - val_accuracy: 0.8864 - val_loss: 0.3244
# Epoch 14/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8886 - loss: 0.2954 - val_accuracy: 0.8876 - val_loss: 0.3214
# Epoch 15/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8914 - loss: 0.2894 - val_accuracy: 0.8854 - val_loss: 0.3186

# %% [markdown]
# # Evaluate model

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# Predict classes
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Metrics
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-score:  {f1:.4f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Test Accuracy: 0.8800
# Test Loss: 0.3379
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Precision: 0.8809
# Recall:    0.8800
# F1-score:  0.8802
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.84      0.81      0.82      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.79      0.79      0.79      1000
#        Dress       0.89      0.90      0.89      1000
#         Coat       0.77      0.81      0.79      1000
#       Sandal       0.97      0.96      0.97      1000
#        Shirt       0.69      0.69      0.69      1000
#      Sneaker       0.92      0.97      0.95      1000
#          Bag       0.96      0.97      0.97      1000
#   Ankle boot       0.98      0.94      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Plot training history

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# #Model Improvement

# %%
improved_model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

improved_model.compile(optimizer='adam',
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

history_improved = improved_model.fit(
    X_train, y_train_cat,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7615 - loss: 0.6702 - val_accuracy: 0.8397 - val_loss: 0.4330
# Epoch 2/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8275 - loss: 0.4715 - val_accuracy: 0.8538 - val_loss: 0.3944
# Epoch 3/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8425 - loss: 0.4289 - val_accuracy: 0.8596 - val_loss: 0.3741
# Epoch 4/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8511 - loss: 0.4085 - val_accuracy: 0.8622 - val_loss: 0.3687
# Epoch 5/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8585 - loss: 0.3885 - val_accuracy: 0.8712 - val_loss: 0.3607
# Epoch 6/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8595 - loss: 0.3814 - val_accuracy: 0.8668 - val_loss: 0.3589
# Epoch 7/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8651 - loss: 0.3679 - val_accuracy: 0.8721 - val_loss: 0.3474
# Epoch 8/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8683 - loss: 0.3550 - val_accuracy: 0.8781 - val_loss: 0.3386
# Epoch 9/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8694 - loss: 0.3540 - val_accuracy: 0.8807 - val_loss: 0.3319
# Epoch 10/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8739 - loss: 0.3428 - val_accuracy: 0.8721 - val_loss: 0.3430
# Epoch 11/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8744 - loss: 0.3354 - val_accuracy: 0.8813 - val_loss: 0.3284
# Epoch 12/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8775 - loss: 0.3322 - val_accuracy: 0.8798 - val_loss: 0.3273
# Epoch 13/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8796 - loss: 0.3255 - val_accuracy: 0.8833 - val_loss: 0.3222
# Epoch 14/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8817 - loss: 0.3183 - val_accuracy: 0.8747 - val_loss: 0.3411
# Epoch 15/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8820 - loss: 0.3188 - val_accuracy: 0.8850 - val_loss: 0.3221
# Epoch 16/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8836 - loss: 0.3138 - val_accuracy: 0.8860 - val_loss: 0.3132
# Epoch 17/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8876 - loss: 0.3059 - val_accuracy: 0.8871 - val_loss: 0.3166
# Epoch 18/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8878 - loss: 0.3047 - val_accuracy: 0.8888 - val_loss: 0.3091
# Epoch 19/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8876 - loss: 0.3007 - val_accuracy: 0.8859 - val_loss: 0.3225
# Epoch 20/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8895 - loss: 0.2981 - val_accuracy: 0.8911 - val_loss: 0.3066

# %% [markdown]
# #Compare results

# %%
# Evaluate on test set
test_loss, test_accuracy = improved_model.evaluate(X_test, y_test_cat, verbose=0)

print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Accuracy: 0.8816
