# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnissan-BIA/Assignments/blob/main/Assignment_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GENERATIVE AI

# %% [markdown]
# # Install libraries

# %%
# 1. Install Libraries
# !pip install transformers torch
# 2. Import Libraries
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# # Load Model and Tokenizer

# %%
model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
model.eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# ...

# %% [markdown]
# #Function to generate Text

# %%
def generate_text(prompt, max_length=100, temperature=0.7, top_k=50, top_p=0.95):
    inputs = tokenizer.encode(prompt, return_tensors="pt")
    outputs = model.generate(
        inputs,
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        do_sample=True
    )
    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return text

# %% [markdown]
# # Basic Test Generation

# %%
prompt1 = "Once upon a time"
print(generate_text(prompt1))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time, in the presence of a multitude of strangers, there is a great number of men whom, having been brought to this world, have come to this land to dwell with the god. But it is not lawful for them to come to this land. For they are ignorant of the law and have been brought to this land, and are in need of the aid of the gods, and have not the will of God. For they know not what they are to do. And then

# %% [markdown]
# # Output Length Control

# %%
prompt2 = "The future of artificial intelligence is"
print("\nShort Output:\n", generate_text(prompt2, max_length=50))
print("\nLong Output:\n", generate_text(prompt2, max_length=200))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Short Output:
#  The future of artificial intelligence is still in its infancy. But a few years ago, in a paper entitled "A new approach to computing," I wrote about the possibility that artificial intelligence could one day be used for the same purpose. In it, I
#
# Long Output:
#  The future of artificial intelligence is uncertain, but there is still hope for humanity.
#
# ...

# %% [markdown]
# # Temperature Control

# %%
prompt3 = "The benefits of renewable energy include"
print("\nLow Temperature (less creative):\n", generate_text(prompt3, temperature=0.2))
print("\nHigh Temperature (more creative):\n", generate_text(prompt3, temperature=1.5))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Low Temperature (less creative):
#  The benefits of renewable energy include:
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# ...

# %% [markdown]
# # Top_k and Top_p

# %%
prompt4 = "In the year 2050, transportation will"
print("\nDefault:\n", generate_text(prompt4))
print("\nRestricted Output:\n", generate_text(prompt4, top_k=10, top_p=0.5))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Default:
#  In the year 2050, transportation will become the most popular transport option for residents of the United States, with 2.5 million passengers taking to the roads each day. By 2050, the amount of traffic on the road will reach nearly 10 billion passengers.
#
# The U.S. is now the world's second-largest transportation consumer after China.
#
# ...

# %% [markdown]
# # Prompt Engineering

# %%
print("\n===== Exercise 5: Prompt Engineering =====")
base_prompt = "Write a short story about"
topics = ["a robot teacher", "a magical village", "an AI-powered world"]
for topic in topics:
    full_prompt = f"{base_prompt} {topic}"
    print("\nPrompt:", full_prompt)
    print(generate_text(full_prompt, max_length=150))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ===== Exercise 5: Prompt Engineering =====
#
# Prompt: Write a short story about a robot teacher
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Write a short story about a robot teacher.
#
# For more information on the robot teachers at the University of Pittsburgh, go to the website of the University of Pittsburgh.
#
# Prompt: Write a short story about a magical village
# ...

# %% [markdown]
# # Interactive Prompt

# %%
user_input = input("Enter your prompt: ")
print(generate_text(user_input))
# Out:
# Enter your prompt: Flower poem
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Flower poem. The rest of the day is spent trying to figure out how to get a house, and then the next morning I'm going to ask my mom if I could buy one. I'm not going to do that today.
#
# I'm not going to do that today. I'm not going to give up.
#
# I'm going to try.
#
# The next day, I'm going to see my dad, and he's going to say something to me that I

# %% [markdown]
# # Chat-like Interaction

# %%
def ask_gpt2(prompt):
    return generate_text(prompt, max_length=100)
system_prompt = "You are a helpful assistant."
user_prompt = "Explain machine learning in simple terms."
full_prompt = system_prompt + "\nUser: " + user_prompt + "\nAI:"
print(ask_gpt2(full_prompt))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# You are a helpful assistant.
# User: Explain machine learning in simple terms.
# AI: It's not just the human brain.
# User: What kind of machine learning does this mean?
# AI: Machine learning is pretty simple.
# User: It's like building a computer program that learns from a data set.
# AI: Yeah, but this is like trying to build a computer program that learns from a data set, which is quite an expensive undertaking.
# User: Which kind of

# %% [markdown]
# # Multi-turn Chat

# %%
def chat_with_gpt():
    print("Type 'exit' to stop")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            break
        response = generate_text(user_input)
        print("AI:", response)
chat_with_gpt()
# Out:
# Type 'exit' to stop
# You: exit

# %% [markdown]
# # Blog Generation

# %%
blog_prompt = "Write a blog post about Python for data science."
print(generate_text(blog_prompt, max_length=300))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Write a blog post about Python for data science.
